# %%
import requests
from bs4 import BeautifulSoup
from dateutil.parser import parse
from datetime import *

# %%
# this function gets the link for each page and returns it
def get_page_link(link, pages):
    page_link = link + str(pages)
    return page_link

# this function gets the link for each property
def listing_page_link(href):
    property_page = 'https://tonaton.com' + str(href)
    return property_page


# this function makes a request to get the page parses it through beautiful soup and returns the content
def get_soup(link):
    req = requests.get(link)
    src = req.content
    soup = BeautifulSoup(src, "lxml")
    return soup

# %%
page = 1 # initializing the first page for scraping
 # Below is the link to all first page of the mobile adverts.
mobile = "https://tonaton.com/en/ads/ghana/mobile-phones?sort=date&order=desc&buy_now=0&urgent=0&page="

while page < 151:
    
    # The mobile search page
    first_page = get_page_link(mobile, page)
    
    # This gets the whole page data
    soup = get_soup(first_page)

    # this by inspection, this code gets the all the apartment listings and saves the object in a listings variable
    listings = soup.find_all("li", class_="normal--2QYVk gtm-normal-ad") 

   
    
    size = '/1000/1000/fitted.jpg'
    page_list = []
    for links in listings:
        for link in links.find_all("a"):
            if link['href'] != '/en/promotions':
                page_list.append(link['href'])
    ad_list=[]
    for ads in page_list:
        advert = listing_page_link(ads)
        ad_list.append(advert)
        ad_soup = get_soup(advert)
        text = ad_soup.find("div", class_="title-container--1PPnS").text.split('Posted on ')
        name = text[0]
        price = int(''.join(ad_soup.find("div", class_="amount--3NTpl").text.split()[1].split(',')))
        condition = ad_soup.find("div", class_="word-break--2nyVq value--1lKHt").text
        location = text[1].split(',')[1].strip()
        region = text[1].split(',')[2].strip()
        image = ad_soup.findAll('img')[2].attrs['src'][:-19] + '600/600/fitted.jpg'
        tim = text[1].split(',')[0][7:]
        dt= datetime.strptime(tim, '%I:%M %p')
        time = dt.time()
        dat = text[1].split(',')[0][:6] + ', 2021'
        dt = parse(dat)
        date = dt.strftime('%Y-%m-%d')
        url = advert
        print(name)
        print(price)
        print(condition)
        print(location)
        print(region)
        print(image)
        print(time)
        print(date)
        print(url)
        print(' ')
        print(' ')
    
    print('Page ' + str(page) + ' completed')
    
    page = page + 1
# Out:
# Apple iPhone 7 32GB Free🛵 (New)
# 1050
# New
# East Legon
# Greater Accra
# https://i.tonaton-st.com/apple-iphone-7-32gb-free-delivery-new-for-sale-accra-30/8c703c58-4653-4d9f-aa22-033a15b2e176/600/600/fitted.jpg
# 09:36:00
# 2021-10-30
# https://tonaton.com/en/ad/apple-iphone-7-32gb-free-new-for-sale-accra
#
#
# Google pixel 6 (New)
# 5000
# New
# Ga East Municipal
# Greater Accra
# https://i.tonaton-st.com/google-pixel-4a-used-for-sale-greater-accra-3/fc02714a-a9ae-419d-ba2a-caa1fb4ea5f8/600/600/fitted.jpg
# 09:26:00
# 2021-10-30
# https://tonaton.com/en/ad/google-pixel-6-new-for-sale-greater-accra
#
#
# Samsung Galaxy S10+ SEALED 🔥🔥 (New)
# 2500
# New
# East Legon
# Greater Accra
# https://i.tonaton-st.com/apple-iphone-x-256g-sealed-new-for-sale-greater-accra/b18a5d66-d8ca-4d0f-9a69-968ec14b4e15/600/600/fitted.jpg
# 09:25:00
# 2021-10-30
# https://tonaton.com/en/ad/samsung-galaxy-s10-sealed-new-for-sale-greater-accra-1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ccd98212251a> in <module>
#      26         advert = listing_page_link(ads)
#      27         ad_list.append(advert)
# ---> 28         ad_soup = get_soup(advert)
#      29         text = ad_soup.find("div", class_="title-container--1PPnS").text.split('Posted on ')
#      30         name = text[0]
#
# <ipython-input-5-706b3499142d> in get_soup(link)
#      12 # this function makes a request to get the page parses it through beautiful soup and returns the content
#      13 def get_soup(link):
# ---> 14     req = requests.get(link)
#      15     src = req.content
#      16     soup = BeautifulSoup(src, "lxml")
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# int(''.join(ad_soup.find("div", class_="amount--3NTpl").text.split()[1].split(',')))

# %% [markdown]
# ## JIJI Scrapter

# %%
base = "https://jiji.com.gh/api_web/v1/listing?po=6.2&lsmid=1634035073706&webp=true&slug=mobile-phones&page="
number = 1

# %%
def url_maker(url_base, number):
    url = url_base + str(number)
    return url

# %%
url = url_maker(base, number)

# %%
url
# Out:
# 'https://jiji.com.gh/api_web/v1/listing?po=6.2&lsmid=1634035073706&webp=true&slug=mobile-phones&page=1'

# %%
r = requests.get(url)

items = r.json()

# %%
from datetime import datetime

now = datetime.now().date() # time object

print("now =", now)
# Out:
# now = 2021-10-22

# %%
import requests

def url_maker(url_base, number):
    url = url_base + str(number)
    return url

base = "https://jiji.com.gh/api_web/v1/listing?po=6.2&lsmid=1634035073706&webp=true&slug=mobile-phones&page="
number = 1

while number < 50:
    site = url_maker(base, number)
    r = requests.get(site)
    items = r.json()
    for data in items['adverts_list']['adverts']:
        name = data['title']
        price = int("".join(data['price_obj']['view'].split()[1].split(',')))
        condition = data['attributes'][0][1]
        location = data['region_name']
        region = data['region_parent_name']
        url = 'https://jiji.com.gh' + data['url']
        image = data['image_obj']['url']
        time = datetime.now().strftime("%H:%M:%S")
        date = datetime.now().date()
        time = datetime.now().time()
        print(name)
        print(price)
        print(condition)
        print(location)
        print(region)

        print(image)
        print(time)
        print(date)
        print(url)

        print(' ')
        print(' ')
        
        
        
    print(' ')
    print(' ')
    print('page ' + str(number) + ' completed')
    number = number + 1

    #     print('Title: ' + str(data['title']))
    #     print("Condition: " +  str(data['attributes'][0][1]))
    #     print('Region: ' + str(data['region_parent_name']))
    #     print('Price: ' + str(data['price_obj']['view']))
    #     print(' ')
    #     print(' ')
# Out:
# Apple iPhone 11 Pro Max 256 GB Gold
# 3800
# Used
# Accra Metropolitan
# Greater Accra
# https://pictures-ghana.jijistatic.com/16669107_MzAwLTQwMC02NDE3YjFkMzY1.webp
# 21:08:26.188975
# 2021-11-03
# https://jiji.com.gh/accra-metropolitan/mobile-phones/apple-iphone-11-pro-max-256-gb-gold-hE3tFNnEk6CUOqdMO9jg7Yl7.html?lid=8PLc9SKm8_kZ8PX8&cur_pos=1&pos=1&ads_count=25604&ads_per_page=20&page=1
#
#
# Apple iPhone 11 Pro 256 GB Gold
# 3100
# Used
# Accra Metropolitan
# Greater Accra
# https://pictures-ghana.jijistatic.com/16669159_MzAwLTQwMC01OTRiN2FmNzI5.webp
# 21:08:26.189974
# 2021-11-03
# https://jiji.com.gh/accra-metropolitan/mobile-phones/apple-iphone-11-pro-256-gb-gold-k9g3fDjX9elkuunEtNEZ2Evy.html?lid=8PLc9SKm8_kZ8PX8&cur_pos=2&pos=2&ads_count=25604&ads_per_page=20&page=1
#
#
# New Xiaomi Redmi 9T 128 GB
# 1240
# Brand New
# Madina
# Greater Accra
# https://pictures-ghana.jijistatic.com/11716338_img-20210308-wa0047_300x400.webp
# 21:08:26.189974
# 2021-11-03
# https://jiji.com.gh/madina/mobile-phones/new-xiaomi-redmi-9t-128-gb-O9EpDBuWmyNVhnBWMakbDPz.html?lid=8PLc9SKm8_kZ8PX8&cur_pos=3&pos=3&ads_count=25604&ads_per_page=20&page=1
#
#
# Apple iPhone X 256 GB Black
# 2200
# Used
# Circle
# Greater Accra
# https://pictures-ghana.jijistatic.com/14235957_MzAwLTQwMC1iNzhmY2VjNzU1.webp
# 21:08:26.189974
# 2021-11-03
# https://jiji.com.gh/circle/mobile-phones/apple-iphone
# 2021-11-03
# https://jiji.com.gh/dansoman/mobile-phones/new-apple-iphone-xs-64-gb-gold-rYhsl70xm1P4L7nBzgAb1Y5k.html?lid=GjhL03yaSMWIvQZa&cur_pos=20&pos=20&ads_count=25604&ads_per_page=20&page=2
#
#
#
#
# page 2 completed
# Apple iPhone 11 64 GB Black
# 2800
# Used
# East Legon
# Greater Accra
# https://pictures-ghana.jijistatic.com/14901595_MzAwLTQwMC1iOTA2NjVjNDM3.webp
# 21:08:27.894119
# 2021-11-03
# https://jiji.com.gh/east-legon/mobile-phones/apple-iphone-11-64-gb-black-aa3j4L8gyzpDkIdAxrbl5Xfi.html?lid=e9nyTp0ELIGD8_k5&cur_pos=1&pos=1&ads_count=25604&ads_per_page=20&page=3
#
#
# New LG Wing 5G 128 GB
# 2350
# Brand New
# Circle
# Greater Accra
# https://pictures-ghana.jijistatic.com/15890130_MzAwLTQwMC00YzljM2JkODll.webp
# 21:08:27.895117
# 2021-11-03
# https://jiji.com.gh/circle/mobile-phones/new-lg-wing-5g-128-gb-7Dpi57zRXP3bP221T3KKgcym.html?lid=e9nyTp0ELIGD8_k5&cur_pos=2&pos=2&ads_count=25604&ads_per_page=20&page=3
#
#
# Xiaomi Mi 11 256 GB
# 4299
# Used
# Accra Metropolitan
# Greater Accra
# https://pictures-ghana.jijistatic.com/16249310_MzAwLTQwMC0zOTUwMjc4ODA5.webp
# 21:08:27.895117
# 2021-11-03
# https://jiji.com.gh/accra-metropolitan/mobile-phones/xiaomi-mi-11-256-gb-b0SIL8DrCefnxEmm4g1Lrjz0.html?lid=e9nyTp0ELIGD8_k5&cur_pos=3&pos=3&ads_count=25604&ads_per_page=20&page=3
#
#
# New Tecno Spark 8 64 GB
# 750
# Brand New
# Madina
# Greater Accra
# https://pictures-ghana.jijistatic.com/16609399_MzAwLTIyNS04NmY3YzAxNGE2.webp
# 21:08:27.895117
# 2021-11-03
# https://jiji.com.gh/madina/mobile-phones/new-tecno-spark-8-64-gb-BvlJ9ltnx05y5Qf4zxPv4Fw0.html?lid=e9nyTp0ELIGD8_k5&cur_pos=4&pos=4&ads_count=25604&ads_per_page=20&page=3
#
#
# Apple iPhone 12 Pro Max 256 GB Gold
# 4450
# Used
# Accra Metropolitan
# Greater Accra
# https://pictures-ghana.jijistatic.com/16633796_MzAwLTQwMC04YjM4ZGNjM2Zk.webp
# 21:08:27.895117
# 2021-11-03
# https://jiji.com.gh/accra-metropolitan/mobile-phones/apple-iphone-12-pro-max-256-gb-gold-qaI784Oxf15B09fk5TKDZG3x.html?lid=e9nyTp0ELIGD8_k5&cur_pos=5&pos=5&ads_count=25604&ads_per_page=20&page=3
#
#
# New Vivo V5s 64 GB
# 450
# Brand New
# Madina
# Greater Accra
# https://pictures-ghana.jijistatic.com/15950431_MzAwLTQwMC1iY2IxYmE5NTEw.webp
# 21:08:27.895117
# 2021-11-03
# https://jiji.com.gh/madina/mobile-phones/new-vivo-v5s-64-gb-uDSg9cl4u6jKxQBz3LVLzjOR.html?lid=e9nyTp0ELIGD8_k5&cur_pos=6&pos=6&ads_count=25604&ads_per_page=20&page=3
#
#
# New Motorola Moto X 16 GB Black
# 320
# Brand New
# Kokomlemle
# Greater Accra
# https://pictures-ghana.jijistatic.com/7721925_img-20200824-110748540_300x400.webp
# 21:08:27.896113
# 2021-11-03
# https://jiji.com.gh/kokomlemle/mobile-phones/new-motorola-moto-x-16-gb-black-9PUl3TP2hgV9XWOI40im9jGa.html?lid=e9nyTp0ELIGD8_k5&cur_pos=7&pos=7&ads_count=25604&ads_per_page=20&page=3
#
#
# Google Pixel XL 128 GB Black
# 1400
# Used
# Airport Residential Area
# Greater Accra
# https://pictures-ghana.jijistatic.com/8922288_img-20201017-wa0052_300x400.webp
# 21:08:27.896113
# 2021-11-03
# https://jiji.com.gh/airport-residential-area/mobile-phones/google-pixel-xl-128-gb-black-xboI249maNcahWy72nfrpVE2.html?lid=e9nyTp0ELIGD8_k5&cur_pos=8&pos=8&ads_count=25604&ads_per_page=20&page=3
#
#
# LG Velvet 128 GB Silver
# 1800
# Used
# Lapaz
# Greater Accra
# https://pictures-ghana.jijistatic.com/16387938_MzAwLTQwMC04NDRlNGQzYzJj.webp
# 21:08:27.897111
# 2021-11-03
# https://jiji.com.gh/lapaz/mobile-phones/lg-velvet-128-gb-silver-jP8VWoAm4Jn8QaD1peKTF32c.html?lid=e9nyTp0ELIGD8_k5&cur_pos=9&pos=9&ads_count=25604&ads_per_page=20&page=3
#
#
# Apple iPhone 12 256 GB Pink
# 4000
# Used
# Accra Metropolitan
# Greater Accra
# https://pictures-ghana.jijistatic.com/16278907_MzAwLTQwMC0zYjE0Y2U4Njk3.webp
# 21:08:27.897111
# 2021-11-03
# https://jiji.com.gh/accra-metropolitan/mobile-phones/apple-iphone-12-256-gb-pink-iVfqaocaYSxxYd2lNWY9nVGy.html?lid=e9nyTp0ELIGD8_k5&cur_pos=10&pos=10&ads_count=25604&ads_per_page=20&page
ads_count=25604&ads_per_page=20&page=7
#
#
# New Apple iPhone XR 64 GB Silver
# 2430
# Brand New
# Circle
# Greater Accra
# https://pictures-ghana.jijistatic.com/15059603_MzAwLTI2OS1lZTBmNGFhYzA1.webp
# 21:08:31.258148
# 2021-11-03
# https://jiji.com.gh/circle/mobile-phones/new-apple-iphone-xr-64-gb-silver-u4Wvg1aPXszH0Tg2NRH9ANKp.html?lid=l3QIC8YE9UgtuhPt&cur_pos=19&pos=19&ads_count=25604&ads_per_page=20&page=7
#
#
# New Apple iPhone 8 256 GB
# 1850
# Brand New
# Circle
# Greater Accra
# https://pictures-ghana.jijistatic.com/12718873_MzAwLTMxNy1iZGRhNWIwOTBk.webp
# 21:08:31.259145
# 2021-11-03
# https://jiji.com.gh/circle/mobile-phones/new-apple-iphone-8-256-gb-eV7aTSMHhjaCdGa81AnA9eXs.html?lid=l3QIC8YE9UgtuhPt&cur_pos=20&pos=20&ads_count=25604&ads_per_page=20&page=7
#
#
#
#
# page 7 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-b793f85ac77e> in <module>
#      10 while number < 50:
#      11     site = url_maker(base, number)
# ---> 12     r = requests.get(site)
#      13     items = r.json()
#      14     for data in items['adverts_list']['adverts']:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from datetime import *
tim = '3:06 pm'
dt= datetime.strptime(tim, '%I:%M %p')
time = dt.time()
# Out:
# 15:06:00

# %%
int("".join(data['price_obj']['view'].split()[1].split(',')))
# Out:
# 370

# %%
data['image_obj']['url']
# Out:
# 'https://pictures-ghana.jijistatic.com/9713043__300x400.webp'

# %%
time = datetime.now().strftime("%H:%M:%S")
time
# Out:
# '15:48:36'

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://po:password@hostname/database_name')

# %%
link = "https://tonaton.com/en/ad/apple-iphone-3-pro-max-new-for-sale-greater-accra-1"

# %%
ad_soup = get_soup(link)
text = ad_soup.find("div", class_="title-container--1PPnS").text.split('Posted on ')
name = text[0]
price = int(''.join(ad_soup.find("div", class_="amount--3NTpl").text.split()[1].split(',')))
condition = ad_soup.find("div", class_="word-break--2nyVq value--1lKHt").text
location = text[1].split(',')[1].strip()
region = text[1].split(',')[2].strip()
image = ad_soup.findAll('img')[2].attrs['src'][:-19] + '600/600/fitted.jpg'
tim = text[1].split(',')[0][7:]
dt= datetime.strptime(tim, '%I:%M %p')
time = dt.time()
dat = text[1].split(',')[0][:6] + ', 2021'
dt = parse(dat)
date = dt.strftime('%Y-%m-%d')
url = advert
print(name)
print(price)
print(condition)
print(location)
print(region)
print(image)
print(time)
print(date)
print(url)
print(' ')
print(' ')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-7e951f03df62> in <module>
#       6 location = text[1].split(',')[1].strip()
#       7 region = text[1].split(',')[2].strip()
# ----> 8 image = ad_soup.findAll('img')[2].attrs['src'][:-19] + '600/600/fitted.jpg'
#       9 tim = text[1].split(',')[0][7:]
#      10 dt= datetime.strptime(tim, '%I:%M %p')
#
# IndexError: list index out of range

# %%
link = 'https://tonaton.com/en/ad/used-for-sale-ashanti-34'

# %%
ad_soup.findAll('img')
# Out:
# [<img class="logo--6kbta" src="https://i.tonaton-st.com/u/shopify-telecom-limited/1d632676-281d-4afd-ae6b-55534322c1e7/72/54/cropped.jpg"/>,
#  <img src="https://i.tonaton-st.com/u/shopify-telecom-limited/1d632676-281d-4afd-ae6b-55534322c1e7/48/36/cropped.jpg"/>,
#  <img alt="Apple iPhone 11 64GB Limited Stock🔥 (Used)" class="normal-ad--1TyjD" data-testid="" loading="lazy" src="https://i.tonaton-st.com/apple-iphone-11-64gb-limited-stock-used-for-sale-kumasi/2c3fe541-64ea-4f50-ab3e-a600e5ef6fb4/142/107/cropped.jpg"/>,
#  <img alt="Apple iPhone 11 64GB limited Stock (Used)" class="normal-ad--1TyjD" data-testid="" loading="lazy" src="https://i.tonaton-st.com/apple-iphone-11-64gb-limited-stock-used-for-sale-ashanti/fcfb7ad9-e1da-473b-bbfe-4287c434868e/142/107/cropped.jpg"/>,
#  <img alt="Apple iPhone 11 Pro Max 256GB Limited stock (Used)" class="normal-ad--1TyjD" data-testid="" loading="lazy" src="https://i.tonaton-st.com/apple-iphone-11-pro-max-256gb-limited-stock-used-for-sale-kumasi/d31396ec-daa6-44cd-9848-b4d8158d328a/142/107/cropped.jpg"/>,
#  <img alt="Apple iPhone 11 Pro 64GB Stock Limited (Used)" class="normal-ad--1TyjD" data-testid="" loading="lazy" src="https://i.tonaton-st.com/apple-iphone-11-pro-64gb-stock-limited-used-for-sale-ashanti/9d58908c-5fb5-4d8e-92aa-24dc7c1c77e9/142/107/cropped.jpg"/>]

# %%
 ad_soup.findAll('img')[2].attrs['src'][:-19] + '600/600/fitted.jpg'
# Out:
# 'https://i.tonaton-st.com/samsung-galaxy-a224-64-new-for-sale-greater-accra-2/c78bfc1e-7a6f-4e37-b496-60cd9273e4ec/600/600/fitted.jpg'

# %%
link = "https://tonaton.com/en/ad/apple-iphone-8-plus-64gb-used-for-sale-brong-ahafo"

# %%
ad_soup.findAll('img')[0].attrs['src']
# Out:
# dict_keys(['class'])

# %%
ad_soup = get_soup(link)
text = ad_soup.find("div", class_="title-container--1PPnS").text.split('Posted on ')
name = text[0]
price = int(''.join(ad_soup.find("div", class_="amount--3NTpl").text.split()[1].split(',')))
condition = ad_soup.find("div", class_="word-break--2nyVq value--1lKHt").text
location = text[1].split(',')[1].strip()
region = text[1].split(',')[2].strip()
image = ad_soup.findAll('img')[2].attrs['src'][:-19] + '600/600/fitted.jpg'
tim = text[1].split(',')[0][7:]
dt= datetime.strptime(tim, '%I:%M %p')
time = dt.time()
dat = text[1].split(',')[0][:6] + ', 2021'
dt = parse(dat)
date = dt.strftime('%Y-%m-%d')
url = advert
print(name)
print(price)
print(condition)
print(location)
print(region)
print(image)
print(time)
print(date)
print(url)
print(' ')
print(' ')
# Out:
# Samsung Galaxy A22 (4/128) (New)
# 1190
# New
# Kwashieman
# Greater Accra
# https://i.tonaton-st.com/samsung-galaxy-a224-64-new-for-sale-greater-accra-2/c78bfc1e-7a6f-4e37-b496-60cd9273e4ec/600/600/fitted.jpg
# 17:52:00
# 2021-11-02
# https://tonaton.comhttps://tonaton.com/en/ad/apple-iphone-3-pro-max-new-for-sale-greater-accra-1

# %%
region.strip()
# Out:
# 'Ashanti'

# %%
 #ths functions gets the id for region    
def get_region_id(region, cur):
    query = "SELECT id FROM search_region where region='{}'".format(region)
    cur.execute(query)
    key = cur.fetchone()[0]
    return key

def create_connection():
    import psycopg2
    connection = psycopg2.connect(user="postgres",
                              password="STpass@9",
                              host="localhost",
                              port="5432",
                              database="phone")
    cur =connection.cursor()
    return connection, cur


def get_region_id(region, cur):
    query = "SELECT id FROM search_region where region='{}'".format(region)
    cur.execute(query)
    key = cur.fetchone()[0]
    return key

# %%
connection, cur = create_connection()

# %%
get_region_id(region, cur)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-992c65e6bd0d> in <module>
# ----> 1 get_region_id(region, cur)
#
# <ipython-input-27-ce603489ee9a> in get_region_id(region, cur)
#      20    query = "SELECT id FROM search_region where region='{}'".format(region)
#      21    cur.execute(query)
# ---> 22    key = cur.fetchone()[0]
#      23    return key
#
# TypeError: 'NoneType' object is not subscriptable

# %%
region = "Greater Accra"

# %%
query = "SELECT id FROM search_region where region='{}'".format(region)
cur.execute(query)

# %%
len(cur.fetchone())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-bd4bb36751e4> in <module>
# ----> 1 len(cur.fetchone())
#
# TypeError: object of type 'NoneType' has no len()

# %%
ad_soup = get_soup(link)

# %%
for a in ad_soup.findAll('img')[0].attrs.keys():
    print(a)
# Out:
# class
# src
# alt
# data-testid
# loading

# %%
region = 'Ashanti Region'

# %%
if 'Region' in region:
    a = region[:-7]
    print(a)
# Out:
# Ashanti

# %%
# This function creates the connection to the database
def create_connection():
    import psycopg2
    connection = psycopg2.connect(user="postgres",
                              password="STpass@9",
                              host="localhost",
                              port="5432",
                              database="phone")
    cur =connection.cursor()
    
    return connection, cur
    
# ths functions gets the id for region    
def get_region_id(region, cur):
    query = "SELECT id FROM search_region where region='{}'".format(region)
    cur.execute(query)
    key = cur.fetchone()[0]
    return key
    
# ths functions gets the id for condition  
def get_condition_id(condition, cur):
    query = "SELECT id FROM search_condition where condition='{}'".format(condition) 
    cur.execute(query)
    key = cur.fetchone()[0]
    return key

# ths functions gets the id for site  
def get_vendor_id(vendor, cur):
    query = "SELECT id FROM search_vendor where vendor='{}'".format(vendor)
    cur.execute(query)
    key = cur.fetchone()[0]
    return key

# this function inserts the data into the database
def insert_data(name, price, location,image, link, time, date, condition_id, region_id, vendor_id, cur):
    quer = "INSERT INTO search_phone(name, price, location, image, link, time, date, condition_id, region_id, vendor_id)"
    val = "VALUES('{}', {}, '{}', '{}', '{}', '{}', '{}', {}, {}, {})".format(name, price, location, image, link, time, date, condition_id, region_id, vendor_id)
    query = quer+val
    cur.execute(query)
    print('Data Inserted')
    return

# this function checks to see if 
def link_url (link, cur):
    query = "SELECT link FROM search_phone where link ='{}'".format(link)
    cur.execute(query)
    key = cur.fetchone()
    return key

# %%
import requests

def url_maker(url_base, number):
    url = url_base + str(number)
    return url

base = "https://jiji.com.gh/api_web/v1/listing?po=6.2&lsmid=1634035073706&webp=true&slug=mobile-phones&page="
number = 1

while number < 50:
    site = url_maker(base, number)
    r = requests.get(site)
    items = r.json()
    for data in items['adverts_list']['adverts']:
        name = data['title']
        price = int("".join(data['price_obj']['view'].split()[1].split(',')))
        condition = data['attributes'][0][1]
        location = data['region_name']
        region = data['region_parent_name']
        url = 'https://jiji.com.gh' + data['url']
        image = data['image_obj']['url']
        time = datetime.now().strftime("%H:%M:%S")
        date = datetime.now().date()
        time = datetime.now().time()
        print(name)
        print(price)
        print(condition)
        print(location)
        print(region)

        print(image)
        print(time)
        print(date)
        print(url)

        print(' ')
        print(' ')
        
        
        
    print(' ')
    print(' ')
    print('page ' + str(number) + ' completed')
    number = number + 1

    #     print('Title: ' + str(data['title']))
    #     print("Condition: " +  str(data['attributes'][0][1]))
    #     print('Region: ' + str(data['region_parent_name']))
    #     print('Price: ' + str(data['price_obj']['view']))
    #     print(' ')
    #     print(' ')
# Out:
# Xiaomi Redmi 7 32 GB Blue
# 410
# Used
# Ablekuma
# Greater Accra
# https://pictures-ghana.jijistatic.com/16638673_MzAwLTQwMC1hNTJkM2RlYzhk.webp
# 21:10:47.662704
# 2021-11-03
# https://jiji.com.gh/ablekuma/mobile-phones/xiaomi-redmi-7-32-gb-blue-n6ESJslvzOB6DN3lCxqGTKdS.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=1&pos=1&ads_count=25606&ads_per_page=20&page=1
#
#
# Apple iPhone X 64 GB White
# 2050
# Used
# Madina
# Greater Accra
# https://pictures-ghana.jijistatic.com/15544262_MzAwLTQwMC04YzYxZWJhN2Ux.webp
# 21:10:47.663490
# 2021-11-03
# https://jiji.com.gh/madina/mobile-phones/apple-iphone-x-64-gb-white-i5fF5CAZ9vJayXdt3Vh4dXNq.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=2&pos=2&ads_count=25606&ads_per_page=20&page=1
#
#
# New Samsung Galaxy A90 5G 128 GB Black
# 1500
# Brand New
# Sunyani Municipal
# Brong Ahafo
# https://pictures-ghana.jijistatic.com/16404858_MzAwLTQwMC1lM2I4NjRhYWM1.webp
# 21:10:47.663698
# 2021-11-03
# https://jiji.com.gh/sunyani-municipal/mobile-phones/new-samsung-galaxy-a90-5g-128-gb-black-2uLR2yJUmnKmKOBKQrv7memJ.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=3&pos=3&ads_count=25606&ads_per_page=20&page=1
#
#
# Huawei Honor 7i 32 GB Blue
# 350
# Used
# Awoshie
# Greater Accra
# https://pictures-ghana.jijistatic.com/15869562_MzAwLTQwMC03MjUyMjE3NTVk.webp
# 21:10:47.663698
# 2021-11-03
# https://jiji.com.gh/awoshie/mobile-phones/huawei-honor-7i-32-gb-blue-oQRHvF6Rp7NdeXMSm90x19jM.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=4&pos=4&ads_count=25606&ads_per_page=20&page=1
#
#
# Apple iPhone 11 Pro Max 256 GB Gold
# 3350
# Used
# Accra Metropolitan
# Greater Accra
# https://pictures-ghana.jijistatic.com/16632918_MzAwLTM3Ny1iMTkzY2EyN2Zi.webp
# 21:10:47.663698
# 2021-11-03
# https://jiji.com.gh/accra-metropolitan/mobile-phones/apple-iphone-11-pro-max-256-gb-gold-abH3yGf3UvXunxumjt1LZN3G.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=5&pos=5&ads_count=25606&ads_per_page=20&page=1
#
#
# New Motorola Moto G6 32 GB Silver
# 530
# Brand New
# Adenta
# Greater Accra
# https://pictures-ghana.jijistatic.com/5955394__300x617.webp
# 21:10:47.663698
# 2021-11-03
# https://jiji.com.gh/adenta-municipal/mobile-phones/new-motorola-moto-g6-32-gb-silver-xcyw3iLekVumTkArVV3D3Z4r.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=6&pos=6&ads_count=25606&ads_per_page=20&page=1
#
#
# New Apple iPhone 13 Pro Max 256 GB Blue
# 8800
# Brand New
# Kumasi Metropolitan
# Ashanti
# https://pictures-ghana.jijistatic.com/15977025_MzAwLTQwMC0xMzAxNmJjZWNi.webp
# 21:10:47.663698
# 2021-11-03
# https://jiji.com.gh/kumasi-metropolitan/mobile-phones/new-apple-iphone-13-pro-max-256-gb-blue-3pymKvILy7zBTXmfS5907cwi.html?lid=y-1DpbJ8LXe_FDRj&cur_pos=7&pos=7&ads_count=25606&ads_per_page=20&page=1
#
#
# Motorola Moto G6 64 GB Black
# 670
# Used
# Adabraka
# Greater Accra
# https://pictures-ghana.jijistatic.com/15977591_MzAwLTQwMC1jOTgzZDk1M2Jh.webp
# 21:10:47.663698
# 2021-11-03
# https://jiji.com.gh/adabraka/mobile-phones/motorola-moto-g6-64-gb-black-bcUDzFRoNI8xydyIdzXwn3O.html?lid=y-1DpbJ8LXe_FDRj&cur_pos
webp
# 21:10:50.628968
# 2021-11-03
# https://jiji.com.gh/kokomlemle/mobile-phones/new-apple-iphone-7-128-gb-black-wiwYXpESVhxrgZW0S50Mzk9x.html?lid=B2uBRz2z3OIHSxjG&cur_pos=18&pos=18&ads_count=25606&ads_per_page=20&page=3
#
#
# Apple iPhone 11 Pro Max 256 GB
# 5200
# Used
# Dansoman
# Greater Accra
# https://pictures-ghana.jijistatic.com/13355339_MzAwLTMxNi1jZWE5ZmY0MTkw.webp
# 21:10:50.628968
# 2021-11-03
# https://jiji.com.gh/dansoman/mobile-phones/apple-iphone-11-pro-max-256-gb-3oTd3PNyxlU0zfyJ32H4Wm03.html?lid=B2uBRz2z3OIHSxjG&cur_pos=19&pos=19&ads_count=25606&ads_per_page=20&page=3
#
#
# New Apple iPhone 7 Plus 256 GB
# 1850
# Brand New
# Kokomlemle
# Greater Accra
# https://pictures-ghana.jijistatic.com/15636810_MzAwLTQwMC01MDgxNzAxYzQy.webp
# 21:10:50.628968
# 2021-11-03
# https://jiji.com.gh/kokomlemle/mobile-phones/new-apple-iphone-7-plus-256-gb-ngH1YKCkqmViUurWmC5nLOlf.html?lid=B2uBRz2z3OIHSxjG&cur_pos=20&pos=20&ads_count=25606&ads_per_page=20&page=3
#
#
#
#
# page 3 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-f61ffd1b6884> in <module>
#      10 while number < 50:
#      11     site = url_maker(base, number)
# ---> 12     r = requests.get(site)
#      13     items = r.json()
#      14     for data in items['adverts_list']['adverts']:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:

# %%
link = "https://jiji.com.gh/kumasi-metropolitan/mobile-phones/new-huawei-y9-prime-2019-128-gb-silver-aabZN8k43DjU4tmRHOuAjo8u.html?lid=G3-ZiNoj0L0KygXy&cur_pos=19&pos=19&ads_count=25598&ads_per_page=20&page=10"

# %%
r = requests.get(link)
a = r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-136-7f19b85b6530> in <module>
#       1 r = requests.get(link)
# ----> 2 a = r.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 4 column 1 (char 3)

# %%
location
# Out:
# 'Kokomlemle'

# %%
vendor = 'Jiji'
connection, cur = create_connection()
with connection:
    region_id = get_region_id(region, cur)
    condition_id = get_condition_id(condition, cur)
    vendor_id = get_vendor_id(vendor, cur)
    if link_url(link, cur) == None:
        insert_data(name, price, location, image, link, time, date, condition_id, region_id, vendor_id, cur)
        print( "{} has been inserted into the database ".format(name))
    else:
        print('Item Already exists')

# %%
from datetime import date

today = date.today()

# dd/mm/YY
d1 = date.today().strftime("%Y-%m-%d")
print("d1 =", d1)

# Textual month, day and year	
d2 = today.strftime("%B %d, %Y")
print("d2 =", d2)

# mm/dd/y
d3 = today.strftime("%m/%d/%y")
print("d3 =", d3)

# Month abbreviation, day and year	
d4 = today.strftime("%b-%d-%Y")
print("d4 =", d4)
# Out:
# d1 = 2021-11-03
# d2 = November 03, 2021
# d3 = 11/03/21
# d4 = Nov-03-2021

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2021, 11, 3, 21, 40, 36, 553194)

# %%
New Motorola Moto G9 Plus 128 GB Gray
1400
Brand New
Airport Residential Area
Greater Accra
https://pictures-ghana.jijistatic.com/14211993_MzAwLTIyNS1kMDc1NDMwNjE5.webp
21:52:49
https://jiji.com.gh/airport-residential-area/mobile-phones/new-motoroQsC_kecal&cur_pos=17&pos=17&ads_count=25597&ads_per_page=20&page=6
